# %%
# Pandas
import pandas as pd

# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
from sqlalchemy import Column, Integer, String, Float

# %%
# Create Engine and Pass in MySQL Connection
engine = create_engine("mysql://root:password@localhost:3306/project_3")
conn = engine.connect()

# %%
# Query All Records in the the Database
data = pd.read_sql("SELECT * FROM listings_data", conn)

# %%
# Preview the Data
data.head()
# Out:
#      id                        listing_url last_scraped  \
# 0   958   https://www.airbnb.com/rooms/958      10/3/18
# 1  5858  https://www.airbnb.com/rooms/5858      10/3/18
# 2  7918  https://www.airbnb.com/rooms/7918      10/3/18
# 3  8142  https://www.airbnb.com/rooms/8142      10/3/18
# 4  8339  https://www.airbnb.com/rooms/8339      10/3/18
#
#                                                 name host_neighbourhood  \
# 0                Bright, Modern Garden Unit - 1BR/1B    Duboce Triangle
# 1                                 Creative Sanctuary     Bernal Heights
# 2         A Friendly Room - UCSF/USF - San Francisco        Cole Valley
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...        Cole Valley
# 4                    Historic Alamo Square Victorian       Alamo Square
#
#    zipcode   latitude   longitude property_type        room_type  \
# 0    94117  37.769310 -122.433856     Apartment  Entire home/apt
# 1    94110  37.745112 -122.421018     Apartment  Entire home/apt
# 2    94117  37.766690 -122.452505     Apartment     Private room
# 3    94117  37.764872 -122.451828     Apartment     Private room
# 4    94117  37.775249 -122.436374         House  Entire home/apt
#
#           ...          number_of_reviews  first_review  last_review  \
# 0         ...                        160       7/23/09      9/17/18
# 1         ...                        112        5/3/09       8/6/17
# 2         ...                         17       8/31/09     11/21/16
# 3         ...                          8        9/8/14      9/12/18
# 4         ...                         27       9/25/09      8/11/18
#
#    review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                    97                     10                        10
# 1                    98                     10                        10
# 2                    85                      8                         8
# 3                    93                      9                         9
# 4                    97                     10                        10
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                    10                          10                     10
# 1                    10                          10                     10
# 2                     9                           9                      9
# 3                    10                          10                      9
# 4                    10                          10                     10
#
#   review_scores_value
# 0                  10
# 1                   9
# 2                   8
# 3                   9
# 4                   9
#
# [5 rows x 40 columns]

# %%
data.T.to_dict()
# Out:
# {0: {'id': 958,
#   'listing_url': 'https://www.airbnb.com/rooms/958',
#   'last_scraped': '10/3/18',
#   'name': 'Bright, Modern Garden Unit - 1BR/1B',
#   'host_neighbourhood': 'Duboce Triangle',
#   'zipcode': 94117,
#   'latitude': 37.76931038,
#   'longitude': -122.4338563,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 3,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$170.00 ',
#   'weekly_price': '$1,120.00 ',
#   'monthly_price': '$4,200.00 ',
#   'security_deposit': '$100.00 ',
#   'cleaning_fee': '$100.00 ',
#   'guests_included': 2,
#   'extra_people': '$25.00 ',
#   'minimum_nights': 1,
#   'maximum_nights': 30,
#   'calendar_updated': 'yesterday',
#   'has_availability': 't',
#   'availability_30': 1,
#   'availability_60': 6,
#   'availability_90': 17,
#   'availability_365': 140,
#   'number_of_reviews': 160,
#   'first_review': '7/23/09',
#   'last_review': '9/17/18',
#   'review_scores_rating': 97,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  1: {'id': 5858,
#   'listing_url': 'https://www.airbnb.com/rooms/5858',
#   'last_scraped': '10/3/18',
#   'name': 'Creative Sanctuary',
#   'host_neighbourhood': 'Bernal Heights',
#   'zipcode': 94110,
#   'latitude': 37.74511233,
#   'longitude': -122.4210179,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 5,
#   'bathrooms': 1.0,
#   'bedrooms': 2,
#   'beds': 3,
#   'bed_type': 'Real Bed',
#   'price': '$235.00 ',
#   'weekly_price': '$1,600.00 ',
#   'monthly_price': '$5,500.00 ',
#   'security_deposit': '',
#   'cleaning_fee': '$100.00 ',
#   'guests_included': 2,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 60,
#   'calendar_updated': '6 weeks ago',
#   'has_availability': 't',
#   'availability_30': 30,
#   'availability_60': 60,
#   'availability_90': 90,
#   'availability_365': 365,
#   'number_of_reviews': 112,
#   'first_review': '5/3/09',
#   'last_review': '8/6/17',
#   'review_scores_rating': 98,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  2: {'id': 7918,
#   'listing_url': 'https://www.airbnb.com/rooms/7918',
#   'last_scraped': '10/3/18',
#   'name': 'A Friendly Room - UCSF/USF - San Francisco',
#   'host_neighbourhood': 'Cole Valley',
#   'zipcode': 94117,
#   'latitude': 37.7666896,
#   'longitude': -122.4525046,
#   'property_type': 'Apartment',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 4.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$65.00 ',
#   'weekly_price': '$485.00 ',
#   'monthly_price': '$1,685.00 ',
#   'security_deposit': '$200.00 ',
#   'cleaning_fee': '$50.00 ',
#   'guests_included': 1,
#   'extra_people': '$12.00 ',
#   'minimum_nights': 32,
#   'maximum_nights': 60,
#   'calendar_updated': '11 months ago',
#   'has_availability': 't',
#   'availability_30': 30,
#   'availability_60': 60,
#   'availability_90': 90,
#   'availability_365': 365,
#   'number_of_reviews': 17,
#   'first_review': '8/31/09',
#   'last_review': '11/21/16',
#   'review_scores_rating': 85,
#   'review_scores_accuracy': 8,
#   'review_scores_cleanliness': 8,
#   'review_scores_checkin': 9,
#   'review_scores_communication': 9,
#   'review_scores_location': 9,
#   'review_scores_value': 8},
#  3: {'id': 8142,
#   'listing_url': 'https://www.airbnb.com/rooms/8142',
#   'last_scraped': '10/3/18',
#   'name': 'Friendly Room Apt. Style -UCSF/USF - San Francisco',
#   'host_neighbourhood': 'Cole Valley',
#   'zipcode': 94117,
#   'latitude': 37.76487219,
#   'longitude': -122.451828,
#   'property_type': 'Apartment',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 4.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$65.00 ',
#   'weekly_price': '$490.00 ',
#   'monthly_price': '$1,685.00 ',
#   'security_deposit': '$200.00 ',
#   'cleaning_fee': '$50.00 ',
#   'guests_included': 1,
#   'extra_people': '$12.00 ',
#   'minimum_nights': 32,
#   'maximum_nights': 90,
#   'calendar_updated': '11 months ago',
#   'has_availability': 't',
#   'availability_30': 11,
#   'availability_60': 27,
#   'availability_90': 57,
#   'availability_365': 332,
#   'number_of_reviews': 8,
#   'first_review': '9/8/14',
#   'last_review': '9/12/18',
#   'review_scores_rating': 93,
#   'review_scores_accuracy': 9,
#   'review_scores_cleanliness': 9,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 9,
#   'review_scores_value': 9},
#  4: {'id': 8339,
#   'listing_url': 'https://www.airbnb.com/rooms/8339',
#   'last_scraped': '10/3/18',
#   'name': 'Historic Alamo Square Victorian',
#   'host_neighbourhood': 'Alamo Square',
#   'zipcode': 94117,
#   'latitude': 37.77524859,
#   'longitude': -122.4363737,
#   'property_type': 'House',
#   'room_type': 'Entire home/apt',
#   'accommodates': 5,
#   'bathrooms': 1.5,
#   'bedrooms': 2,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$785.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$0.00 ',
#   'cleaning_fee': '$225.00 ',
#   'guests_included': 2,
#   'extra_people': '$150.00 ',
#   'minimum_nights': 7,
#   'maximum_nights': 1125,
#   'calendar_updated': '2 weeks ago',
#   'has_availability': 't',
#   'availability_30': 30,
#   'availability_60': 60,
#   'availability_90': 89,
#   'availability_365': 89,
#   'number_of_reviews': 27,
#   'first_review': '9/25/09',
#   'last_review': '8/11/18',
#   'review_scores_rating': 97,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  5: {'id': 8567,
#   'listing_url': 'https://www.airbnb.com/rooms/8567',
#   'last_scraped': '10/3/18',
#   'name': 'Lovely 2BR flat Great Location',
#   'host_neighbourhood': 'Western Addition/NOPA',
#   'zipcode': 94115,
#   'latitude': 37.78470745,
#   'longitude': -122.4455543,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 6,
#   'bathrooms': 1.0,
#   'bedrooms': 2,
#   'beds': 3,
#   'bed_type': 'Real Bed',
#   'price': '$255.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$0.00 ',
#   'cleaning_fee': '$125.00 ',
#   'guests_included': 1,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 2,
#   'maximum_nights': 365,
#   'calendar_updated': '2 months ago',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 6,
#   'availability_90': 6,
#   'availability_365': 41,
#   'number_of_reviews': 31,
#   'first_review': '8/14/09',
#   'last_review': '9/2/18',
#   'review_scores_rating': 90,
#   'review_scores_accuracy': 9,
#   'review_scores_cleanliness': 8,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 9,
#   'review_scores_value': 9},
#  6: {'id': 8739,
#   'listing_url': 'https://www.airbnb.com/rooms/8739',
#   'last_scraped': '10/3/18',
#   'name': 'Mission Sunshine, with Private Bath',
#   'host_neighbourhood': 'Mission District',
#   'zipcode': 94110,
#   'latitude': 37.7591889,
#   'longitude': -122.4223669,
#   'property_type': 'Condominium',
#   'room_type': 'Private room',
#   'accommodates': 3,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$139.00 ',
#   'weekly_price': '',
#   'monthly_price': '$9,999.00 ',
#   'security_deposit': '$0.00 ',
#   'cleaning_fee': '$50.00 ',
#   'guests_included': 2,
#   'extra_people': '$60.00 ',
#   'minimum_nights': 1,
#   'maximum_nights': 14,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 3,
#   'availability_60': 25,
#   'availability_90': 52,
#   'availability_365': 141,
#   'number_of_reviews': 614,
#   'first_review': '8/1/09',
#   'last_review': '9/28/18',
#   'review_scores_rating': 98,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  7: {'id': 9225,
#   'listing_url': 'https://www.airbnb.com/rooms/9225',
#   'last_scraped': '10/3/18',
#   'name': 'Artful Potrero Separate Floor with Garden',
#   'host_neighbourhood': 'Potrero Hill',
#   'zipcode': 94107,
#   'latitude': 37.76258885,
#   'longitude': -122.4054306,
#   'property_type': 'House',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$135.00 ',
#   'weekly_price': '$1,000.00 ',
#   'monthly_price': '$4,000.00 ',
#   'security_deposit': '',
#   'cleaning_fee': '$50.00 ',
#   'guests_included': 1,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 1,
#   'maximum_nights': 365,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 8,
#   'availability_60': 37,
#   'availability_90': 65,
#   'availability_365': 340,
#   'number_of_reviews': 427,
#   'first_review': '10/26/09',
#   'last_review': '9/30/18',
#   'review_scores_rating': 93,
#   'review_scores_accuracy': 9,
#   'review_scores_cleanliness': 9,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  8: {'id': 10251,
#   'listing_url': 'https://www.airbnb.com/rooms/10251',
#   'last_scraped': '10/3/18',
#   'name': 'Victorian Suite in Inner Mission',
#   'host_neighbourhood': 'Mission District',
#   'zipcode': 94110,
#   'latitude': 37.75874295,
#   'longitude': -122.413272,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 6,
#   'bathrooms': 1.0,
#   'bedrooms': 2,
#   'beds': 3,
#   'bed_type': 'Real Bed',
#   'price': '$265.00 ',
#   'weekly_price': '$1,540.00 ',
#   'monthly_price': '$5,400.00 ',
#   'security_deposit': '$500.00 ',
#   'cleaning_fee': '$100.00 ',
#   'guests_included': 4,
#   'extra_people': '$45.00 ',
#   'minimum_nights': 3,
#   'maximum_nights': 30,
#   'calendar_updated': '4 weeks ago',
#   'has_availability': 't',
#   'availability_30': 3,
#   'availability_60': 19,
#   'availability_90': 39,
#   'availability_365': 300,
#   'number_of_reviews': 302,
#   'first_review': '9/12/09',
#   'last_review': '9/15/18',
#   'review_scores_rating': 95,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 9,
#   'review_scores_location': 9,
#   'review_scores_value': 9},
#  9: {'id': 10578,
#   'listing_url': 'https://www.airbnb.com/rooms/10578',
#   'last_scraped': '10/3/18',
#   'name': 'Classic Nob Hill Studio - Roof Deck',
#   'host_neighbourhood': 'Nob Hill',
#   'zipcode': 94109,
#   'latitude': 37.79142746,
#   'longitude': -122.4154357,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 0,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$120.00 ',
#   'weekly_price': '$1,150.00 ',
#   'monthly_price': '$2,875.00 ',
#   'security_deposit': '$500.00 ',
#   'cleaning_fee': '$75.00 ',
#   'guests_included': 2,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 180,
#   'calendar_updated': '3 months ago',
#   'has_availability': 't',
#   'availability_30': 30,
#   'availability_60': 60,
#   'availability_90': 90,
#   'availability_365': 365,
#   'number_of_reviews': 18,
#   'first_review': '12/23/11',
#   'last_review': '5/17/15',
#   'review_scores_rating': 99,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  10: {'id': 10819,
#   'listing_url': 'https://www.airbnb.com/rooms/10819',
#   'last_scraped': '10/3/18',
#   'name': 'Spacious 3BED/2BATH Apartment in Marina District',
#   'host_neighbourhood': 'Cow Hollow',
#   'zipcode': 94111,
#   'latitude': 37.80060136,
#   'longitude': -122.4250454,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 4,
#   'bathrooms': 2.0,
#   'bedrooms': 3,
#   'beds': 3,
#   'bed_type': 'Real Bed',
#   'price': '$218.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$3,000.00 ',
#   'cleaning_fee': '$208.00 ',
#   'guests_included': 6,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 1125,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 0,
#   'availability_90': 1,
#   'availability_365': 276,
#   'number_of_reviews': 22,
#   'first_review': '4/15/13',
#   'last_review': '12/14/15',
#   'review_scores_rating': 88,
#   'review_scores_accuracy': 9,
#   'review_scores_cleanliness': 9,
#   'review_scores_checkin': 9,
#   'review_scores_communication': 8,
#   'review_scores_location': 9,
#   'review_scores_value': 8},
#  11: {'id': 10820,
#   'listing_url': 'https://www.airbnb.com/rooms/10820',
#   'last_scraped': '10/3/18',
#   'name': 'Haight Buena Vista Park Garden 3BR',
#   'host_neighbourhood': 'Cow Hollow',
#   'zipcode': 94117,
#   'latitude': 37.77187372,
#   'longitude': -122.4385911,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 3,
#   'bathrooms': 1.0,
#   'bedrooms': 3,
#   'beds': 3,
#   'bed_type': 'Real Bed',
#   'price': '$177.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$2,500.00 ',
#   'cleaning_fee': '$208.00 ',
#   'guests_included': 6,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 1125,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 1,
#   'availability_90': 31,
#   'availability_365': 306,
#   'number_of_reviews': 36,
#   'first_review': '10/22/09',
#   'last_review': '9/8/18',
#   'review_scores_rating': 89,
#   'review_scores_accuracy': 9,
#   'review_scores_cleanliness': 9,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 9,
#   'review_scores_location': 9,
#   'review_scores_value': 9},
#  12: {'id': 10824,
#   'listing_url': 'https://www.airbnb.com/rooms/10824',
#   'last_scraped': '10/3/18',
#   'name': 'Victorian House in Hayes Valley',
#   'host_neighbourhood': 'Cow Hollow',
#   'zipcode': 94102,
#   'latitude': 37.77355002,
#   'longitude': -122.4243619,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 5,
#   'bathrooms': 2.0,
#   'bedrooms': 3,
#   'beds': 3,
#   'bed_type': 'Real Bed',
#   'price': '$194.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$3,000.00 ',
#   'cleaning_fee': '$208.00 ',
#   'guests_included': 1,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 1125,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 0,
#   'availability_90': 8,
#   'availability_365': 283,
#   'number_of_reviews': 14,
#   'first_review': '3/1/12',
#   'last_review': '8/25/18',
#   'review_scores_rating': 91,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 9,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  13: {'id': 10832,
#   'listing_url': 'https://www.airbnb.com/rooms/10832',
#   'last_scraped': '10/3/18',
#   'name': 'Union Square Modern Loft',
#   'host_neighbourhood': 'Cow Hollow',
#   'zipcode': 94102,
#   'latitude': 37.7857389,
#   'longitude': -122.4079771,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'bathrooms': 1.5,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$139.00 ',
#   'weekly_price': '',
#   'monthly_price': '$4,800.00 ',
#   'security_deposit': '$2,500.00 ',
#   'cleaning_fee': '$130.00 ',
#   'guests_included': 1,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 365,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 22,
#   'availability_60': 22,
#   'availability_90': 39,
#   'availability_365': 314,
#   'number_of_reviews': 18,
#   'first_review': '2/10/13',
#   'last_review': '8/17/18',
#   'review_scores_rating': 91,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 9,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  14: {'id': 12041,
#   'listing_url': 'https://www.airbnb.com/rooms/12041',
#   'last_scraped': '10/3/18',
#   'name': 'Sunny/Sunset view room UCSF/USF - San Francisco',
#   'host_neighbourhood': 'Cole Valley',
#   'zipcode': 94117,
#   'latitude': 37.77018946,
#   'longitude': -122.4459422,
#   'property_type': 'Apartment',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 4.0,
#   'bedrooms': 1,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$85.00 ',
#   'weekly_price': '$630.00 ',
#   'monthly_price': '$1,995.00 ',
#   'security_deposit': '$200.00 ',
#   'cleaning_fee': '$50.00 ',
#   'guests_included': 1,
#   'extra_people': '$12.00 ',
#   'minimum_nights': 32,
#   'maximum_nights': 60,
#   'calendar_updated': '16 months ago',
#   'has_availability': 't',
#   'availability_30': 30,
#   'availability_60': 60,
#   'availability_90': 90,
#   'availability_365': 365,
#   'number_of_reviews': 6,
#   'first_review': '9/18/11',
#   'last_review': '9/20/18',
#   'review_scores_rating': 80,
#   'review_scores_accuracy': 9,
#   'review_scores_cleanliness': 8,
#   'review_scores_checkin': 9,
#   'review_scores_communication': 10,
#   'review_scores_location': 9,
#   'review_scores_value': 7},
#  15: {'id': 12042,
#   'listing_url': 'https://www.airbnb.com/rooms/12042',
#   'last_scraped': '10/3/18',
#   'name': 'Sunny/Sunset view room UCSF/USF - San Francisco',
#   'host_neighbourhood': 'Cole Valley',
#   'zipcode': 94117,
#   'latitude': 37.76894262,
#   'longitude': -122.4477822,
#   'property_type': 'Apartment',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 3.0,
#   'bedrooms': 1,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$85.00 ',
#   'weekly_price': '$630.00 ',
#   'monthly_price': '$1,995.00 ',
#   'security_deposit': '$200.00 ',
#   'cleaning_fee': '$50.00 ',
#   'guests_included': 1,
#   'extra_people': '$12.00 ',
#   'minimum_nights': 32,
#   'maximum_nights': 90,
#   'calendar_updated': '16 months ago',
#   'has_availability': 't',
#   'availability_30': 30,
#   'availability_60': 60,
#   'availability_90': 90,
#   'availability_365': 365,
#   'number_of_reviews': 5,
#   'first_review': '5/6/13',
#   'last_review': '10/18/15',
#   'review_scores_rating': 64,
#   'review_scores_accuracy': 6,
#   'review_scores_cleanliness': 6,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 9,
#   'review_scores_location': 9,
#   'review_scores_value': 8},
#  16: {'id': 12522,
#   'listing_url': 'https://www.airbnb.com/rooms/12522',
#   'last_scraped': '10/3/18',
#   'name': 'Perfectly located Castro',
#   'host_neighbourhood': 'The Castro',
#   'zipcode': 94114,
#   'latitude': 37.76074548,
#   'longitude': -122.4303241,
#   'property_type': 'Apartment',
#   'room_type': 'Private room',
#   'accommodates': 1,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$79.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '',
#   'cleaning_fee': '$10.00 ',
#   'guests_included': 1,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 3,
#   'maximum_nights': 27,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 9,
#   'availability_90': 21,
#   'availability_365': 21,
#   'number_of_reviews': 375,
#   'first_review': '1/14/10',
#   'last_review': '9/29/18',
#   'review_scores_rating': 98,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  17: {'id': 12584,
#   'listing_url': 'https://www.airbnb.com/rooms/12584',
#   'last_scraped': '10/3/18',
#   'name': '3 levels, Views, 2BR/1BA',
#   'host_neighbourhood': 'Cole Valley',
#   'zipcode': 94117,
#   'latitude': 37.76203102,
#   'longitude': -122.4545495,
#   'property_type': 'Townhouse',
#   'room_type': 'Entire home/apt',
#   'accommodates': 5,
#   'bathrooms': 1.0,
#   'bedrooms': 2,
#   'beds': 5,
#   'bed_type': 'Real Bed',
#   'price': '$146.00 ',
#   'weekly_price': '$1,600.00 ',
#   'monthly_price': '$4,600.00 ',
#   'security_deposit': '$899.00 ',
#   'cleaning_fee': '$299.00 ',
#   'guests_included': 2,
#   'extra_people': '$21.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 800,
#   'calendar_updated': '2 months ago',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 14,
#   'availability_90': 44,
#   'availability_365': 319,
#   'number_of_reviews': 15,
#   'first_review': '10/14/12',
#   'last_review': '9/7/18',
#   'review_scores_rating': 94,
#   'review_scores_accuracy': 8,
#   'review_scores_cleanliness': 9,
#   'review_scores_checkin': 9,
#   'review_scores_communication': 9,
#   'review_scores_location': 9,
#   'review_scores_value': 9},
#  18: {'id': 14125,
#   'listing_url': 'https://www.airbnb.com/rooms/14125',
#   'last_scraped': '10/3/18',
#   'name': 'Gallery Residence',
#   'host_neighbourhood': 'Mission District',
#   'zipcode': 94110,
#   'latitude': 37.7549067,
#   'longitude': -122.422455,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 3,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$215.00 ',
#   'weekly_price': '',
#   'monthly_price': '$5,500.00 ',
#   'security_deposit': '',
#   'cleaning_fee': '$80.00 ',
#   'guests_included': 2,
#   'extra_people': '$35.00 ',
#   'minimum_nights': 3,
#   'maximum_nights': 10,
#   'calendar_updated': 'a week ago',
#   'has_availability': 't',
#   'availability_30': 1,
#   'availability_60': 16,
#   'availability_90': 32,
#   'availability_365': 274,
#   'number_of_reviews': 94,
#   'first_review': '1/18/10',
#   'last_review': '8/10/18',
#   'review_scores_rating': 98,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  19: {'id': 17132,
#   'listing_url': 'https://www.airbnb.com/rooms/17132',
#   'last_scraped': '10/3/18',
#   'name': 'Luxury 2BR suite with waterview',
#   'host_neighbourhood': 'El Grenada',
#   'zipcode': 94105,
#   'latitude': 37.78646668,
#   'longitude': -122.390717,
#   'property_type': 'Condominium',
#   'room_type': 'Entire home/apt',
#   'accommodates': 4,
#   'bathrooms': 2.0,
#   'bedrooms': 2,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$450.00 ',
#   'weekly_price': '$2,300.00 ',
#   'monthly_price': '$6,600.00 ',
#   'security_deposit': '$5,000.00 ',
#   'cleaning_fee': '$250.00 ',
#   'guests_included': 4,
#   'extra_people': '$100.00 ',
#   'minimum_nights': 35,
#   'maximum_nights': 1124,
#   'calendar_updated': '5 months ago',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 0,
#   'availability_90': 0,
#   'availability_365': 274,
#   'number_of_reviews': 14,
#   'first_review': '12/11/10',
#   'last_review': '9/29/16',
#   'review_scores_rating': 96,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  20: {'id': 18231,
#   'listing_url': 'https://www.airbnb.com/rooms/18231',
#   'last_scraped': '10/3/18',
#   'name': 'Loft-like Apt./Garden (monthly only available)',
#   'host_neighbourhood': 'Noe Valley',
#   'zipcode': 94114,
#   'latitude': 37.74888371,
#   'longitude': -122.4298237,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 3,
#   'bathrooms': 1.0,
#   'bedrooms': 0,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$107.00 ',
#   'weekly_price': '',
#   'monthly_price': '$3,200.00 ',
#   'security_deposit': '',
#   'cleaning_fee': '',
#   'guests_included': 2,
#   'extra_people': '$20.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 365,
#   'calendar_updated': '5 weeks ago',
#   'has_availability': 't',
#   'availability_30': 6,
#   'availability_60': 6,
#   'availability_90': 7,
#   'availability_365': 71,
#   'number_of_reviews': 59,
#   'first_review': '6/5/10',
#   'last_review': '5/1/18',
#   'review_scores_rating': 96,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  21: {'id': 18904,
#   'listing_url': 'https://www.airbnb.com/rooms/18904',
#   'last_scraped': '10/3/18',
#   'name': 'Tranquil Lower Haight w/pvt bath',
#   'host_neighbourhood': 'Lower Haight',
#   'zipcode': 94117,
#   'latitude': 37.77252152,
#   'longitude': -122.4321565,
#   'property_type': 'Townhouse',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$110.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$130.00 ',
#   'cleaning_fee': '$30.00 ',
#   'guests_included': 1,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 2,
#   'maximum_nights': 29,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 7,
#   'availability_60': 31,
#   'availability_90': 60,
#   'availability_365': 60,
#   'number_of_reviews': 339,
#   'first_review': '12/5/11',
#   'last_review': '9/25/18',
#   'review_scores_rating': 97,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  22: {'id': 19040,
#   'listing_url': 'https://www.airbnb.com/rooms/19040',
#   'last_scraped': '10/3/18',
#   'name': 'Mission Garden Retreat',
#   'host_neighbourhood': 'Mission District',
#   'zipcode': 94110,
#   'latitude': 37.76348967,
#   'longitude': -122.415174,
#   'property_type': 'Guest suite',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 0,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$198.00 ',
#   'weekly_price': '$1,188.00 ',
#   'monthly_price': '$3,888.00 ',
#   'security_deposit': '$333.00 ',
#   'cleaning_fee': '$38.00 ',
#   'guests_included': 2,
#   'extra_people': '$20.00 ',
#   'minimum_nights': 5,
#   'maximum_nights': 28,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 0,
#   'availability_90': 0,
#   'availability_365': 0,
#   'number_of_reviews': 225,
#   'first_review': '3/3/10',
#   'last_review': '7/22/18',
#   'review_scores_rating': 96,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 9,
#   'review_scores_value': 9},
#  23: {'id': 21334,
#   'listing_url': 'https://www.airbnb.com/rooms/21334',
#   'last_scraped': '10/3/18',
#   'name': 'Studio loft on top of Russian Hill',
#   'host_neighbourhood': 'Nob Hill',
#   'zipcode': 94133,
#   'latitude': 37.79579579,
#   'longitude': -122.4153345,
#   'property_type': 'Loft',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$150.00 ',
#   'weekly_price': '$1,220.00 ',
#   'monthly_price': '$4,305.00 ',
#   'security_deposit': '$500.00 ',
#   'cleaning_fee': '$60.00 ',
#   'guests_included': 1,
#   'extra_people': '$25.00 ',
#   'minimum_nights': 4,
#   'maximum_nights': 14,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 6,
#   'availability_60': 28,
#   'availability_90': 57,
#   'availability_365': 57,
#   'number_of_reviews': 114,
#   'first_review': '5/13/10',
#   'last_review': '9/21/18',
#   'review_scores_rating': 98,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 9,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  24: {'id': 21914,
#   'listing_url': 'https://www.airbnb.com/rooms/21914',
#   'last_scraped': '10/3/18',
#   'name': 'A Friendly Room Apt. Style-UCSF/USF-San Francisco',
#   'host_neighbourhood': 'Cole Valley',
#   'zipcode': 94117,
#   'latitude': 37.7648003,
#   'longitude': -122.4525132,
#   'property_type': 'Apartment',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 4.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$65.00 ',
#   'weekly_price': '$490.00 ',
#   'monthly_price': '$1,685.00 ',
#   'security_deposit': '$200.00 ',
#   'cleaning_fee': '$50.00 ',
#   'guests_included': 1,
#   'extra_people': '$12.00 ',
#   'minimum_nights': 32,
#   'maximum_nights': 90,
#   'calendar_updated': '16 months ago',
#   'has_availability': 't',
#   'availability_30': 30,
#   'availability_60': 60,
#   'availability_90': 90,
#   'availability_365': 365,
#   'number_of_reviews': 14,
#   'first_review': '9/18/11',
#   'last_review': '8/16/17',
#   'review_scores_rating': 78,
#   'review_scores_accuracy': 8,
#   'review_scores_cleanliness': 8,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 7},
#  25: {'id': 23540,
#   'listing_url': 'https://www.airbnb.com/rooms/23540',
#   'last_scraped': '10/3/18',
#   'name': 'Modern in-Law Unit in the Happening',
#   'host_neighbourhood': 'Mission District',
#   'zipcode': 94110,
#   'latitude': 37.75065033,
#   'longitude': -122.4198382,
#   'property_type': 'Guest suite',
#   'room_type': 'Entire home/apt',
#   'accommodates': 5,
#   'bathrooms': 1.0,
#   'bedrooms': 2,
#   'beds': 4,
#   'bed_type': 'Real Bed',
#   'price': '$225.00 ',
#   'weekly_price': '$1,500.00 ',
#   'monthly_price': '$5,000.00 ',
#   'security_deposit': '$500.00 ',
#   'cleaning_fee': '$100.00 ',
#   'guests_included': 4,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 1,
#   'maximum_nights': 30,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 1,
#   'availability_60': 3,
#   'availability_90': 3,
#   'availability_365': 3,
#   'number_of_reviews': 101,
#   'first_review': '3/23/10',
#   'last_review': '9/24/18',
#   'review_scores_rating': 97,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  26: {'id': 23611,
#   'listing_url': 'https://www.airbnb.com/rooms/23611',
#   'last_scraped': '10/3/18',
#   'name': 'Bernal Heights Gem with Fab Views !',
#   'host_neighbourhood': 'Bernal Heights',
#   'zipcode': 94110,
#   'latitude': 37.74556319,
#   'longitude': -122.4120681,
#   'property_type': 'Condominium',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$100.00 ',
#   'weekly_price': '$750.00 ',
#   'monthly_price': '$2,800.00 ',
#   'security_deposit': '$500.00 ',
#   'cleaning_fee': '$30.00 ',
#   'guests_included': 1,
#   'extra_people': '$30.00 ',
#   'minimum_nights': 3,
#   'maximum_nights': 29,
#   'calendar_updated': '2 weeks ago',
#   'has_availability': 't',
#   'availability_30': 14,
#   'availability_60': 44,
#   'availability_90': 74,
#   'availability_365': 348,
#   'number_of_reviews': 227,
#   'first_review': '4/19/10',
#   'last_review': '10/1/18',
#   'review_scores_rating': 98,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  27: {'id': 23630,
#   'listing_url': 'https://www.airbnb.com/rooms/23630',
#   'last_scraped': '10/3/18',
#   'name': 'Castro Guest Suite With Continental Breakfast',
#   'host_neighbourhood': 'The Castro',
#   'zipcode': 94114,
#   'latitude': 37.75963016,
#   'longitude': -122.4414323,
#   'property_type': 'House',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$155.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$200.00 ',
#   'cleaning_fee': '',
#   'guests_included': 2,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 3,
#   'maximum_nights': 14,
#   'calendar_updated': 'a week ago',
#   'has_availability': 't',
#   'availability_30': 2,
#   'availability_60': 11,
#   'availability_90': 21,
#   'availability_365': 267,
#   'number_of_reviews': 332,
#   'first_review': '6/16/10',
#   'last_review': '9/20/18',
#   'review_scores_rating': 97,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  28: {'id': 23680,
#   'listing_url': 'https://www.airbnb.com/rooms/23680',
#   'last_scraped': '10/3/18',
#   'name': 'Central Location & Golden Gate View',
#   'host_neighbourhood': 'Pacific Heights',
#   'zipcode': 94109,
#   'latitude': 37.7931804,
#   'longitude': -122.4277325,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$199.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$500.00 ',
#   'cleaning_fee': '$85.00 ',
#   'guests_included': 2,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 5,
#   'maximum_nights': 29,
#   'calendar_updated': '3 days ago',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 0,
#   'availability_90': 0,
#   'availability_365': 0,
#   'number_of_reviews': 24,
#   'first_review': '3/31/10',
#   'last_review': '9/30/18',
#   'review_scores_rating': 99,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  29: {'id': 24390,
#   'listing_url': 'https://www.airbnb.com/rooms/24390',
#   'last_scraped': '10/3/18',
#   'name': 'Mission Studio',
#   'host_neighbourhood': 'Mission District',
#   'zipcode': 94110,
#   'latitude': 37.75145556,
#   'longitude': -122.4124782,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$95.00 ',
#   'weekly_price': '$945.00 ',
#   'monthly_price': '$2,950.00 ',
#   'security_deposit': '$2,000.00 ',
#   'cleaning_fee': '$75.00 ',
#   'guests_included': 2,
#   'extra_people': '$104.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 356,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 1,
#   'availability_60': 2,
#   'availability_90': 19,
#   'availability_365': 108,
#   'number_of_reviews': 64,
#   'first_review': '12/2/10',
#   'last_review': '4/9/18',
#   'review_scores_rating': 96,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 9,
#   'review_scores_value': 9},
#  30: {'id': 24450,
#   'listing_url': 'https://www.airbnb.com/rooms/24450',
#   'last_scraped': '10/3/18',
#   'name': 'Atelier Noe 25 Studio in Noe Valley',
#   'host_neighbourhood': 'Noe Valley',
#   'zipcode': 94114,
#   'latitude': 37.74884818,
#   'longitude': -122.436726,
#   'property_type': 'House',
#   'room_type': 'Entire home/apt',
#   'accommodates': 3,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$199.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$250.00 ',
#   'cleaning_fee': '$90.00 ',
#   'guests_included': 2,
#   'extra_people': '$25.00 ',
#   'minimum_nights': 2,
#   'maximum_nights': 28,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 6,
#   'availability_60': 35,
#   'availability_90': 65,
#   'availability_365': 67,
#   'number_of_reviews': 203,
#   'first_review': '4/26/10',
#   'last_review': '9/28/18',
#   'review_scores_rating': 92,
#   'review_scores_accuracy': 9,
#   'review_scores_cleanliness': 9,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  31: {'id': 24463,
#   'listing_url': 'https://www.airbnb.com/rooms/24463',
#   'last_scraped': '10/3/18',
#   'name': 'Potrero Hill "Nest" Quiet, Comfy & Convenient',
#   'host_neighbourhood': 'Potrero Hill',
#   'zipcode': 94107,
#   'latitude': 37.75644595,
#   'longitude': -122.3991023,
#   'property_type': 'Townhouse',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$155.00 ',
#   'weekly_price': '$1,021.00 ',
#   'monthly_price': '$3,200.00 ',
#   'security_deposit': '$500.00 ',
#   'cleaning_fee': '$80.00 ',
#   'guests_included': 2,
#   'extra_people': '$20.00 ',
#   'minimum_nights': 2,
#   'maximum_nights': 29,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 9,
#   'availability_60': 30,
#   'availability_90': 60,
#   'availability_365': 149,
#   'number_of_reviews': 259,
#   'first_review': '5/31/10',
#   'last_review': '9/28/18',
#   'review_scores_rating': 97,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  32: {'id': 24723,
#   'listing_url': 'https://www.airbnb.com/rooms/24723',
#   'last_scraped': '10/3/18',
#   'name': 'Apartment-like rooms in PacHeights',
#   'host_neighbourhood': 'Western Addition/NOPA',
#   'zipcode': 94115,
#   'latitude': 37.78716465,
#   'longitude': -122.4338611,
#   'property_type': 'Guest suite',
#   'room_type': 'Entire home/apt',
#   'accommodates': 4,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$195.00 ',
#   'weekly_price': '$1,049.00 ',
#   'monthly_price': '$3,336.00 ',
#   'security_deposit': '$0.00 ',
#   'cleaning_fee': '$20.00 ',
#   'guests_included': 4,
#   'extra_people': '$20.00 ',
#   'minimum_nights': 5,
#   'maximum_nights': 31,
#   'calendar_updated': '4 days ago',
#   'has_availability': 't',
#   'availability_30': 4,
#   'availability_60': 11,
#   'availability_90': 18,
#   'availability_365': 148,
#   'number_of_reviews': 259,
#   'first_review': '4/9/10',
#   'last_review': '9/29/18',
#   'review_scores_rating': 95,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  33: {'id': 25094,
#   'listing_url': 'https://www.airbnb.com/rooms/25094',
#   'last_scraped': '10/3/18',
#   'name': "San Francisco's Luxury Oasis On Noe",
#   'host_neighbourhood': 'Glen Park',
#   'zipcode': 94131,
#   'latitude': 37.74187613,
#   'longitude': -122.4312154,
#   'property_type': 'House',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$150.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '',
#   'cleaning_fee': '$25.00 ',
#   'guests_included': 1,
#   'extra_people': '$10.00 ',
#   'minimum_nights': 5,
#   'maximum_nights': 28,
#   'calendar_updated': '2 weeks ago',
#   'has_availability': 't',
#   'availability_30': 11,
#   'availability_60': 34,
#   'availability_90': 59,
#   'availability_365': 334,
#   'number_of_reviews': 23,
#   'first_review': '6/21/16',
#   'last_review': '9/15/18',
#   'review_scores_rating': 100,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  34: {'id': 25168,
#   'listing_url': 'https://www.airbnb.com/rooms/25168',
#   'last_scraped': '10/3/18',
#   'name': '*CHARMING & BRIGHT* All-Inclusive!',
#   'host_neighbourhood': 'Presidio Heights',
#   'zipcode': 94118,
#   'latitude': 37.78962992,
#   'longitude': -122.4487778,
#   'property_type': 'Apartment',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$125.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$0.00 ',
#   'cleaning_fee': '$0.00 ',
#   'guests_included': 1,
#   'extra_people': '$45.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 360,
#   'calendar_updated': '3 weeks ago',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 0,
#   'availability_90': 30,
#   'availability_365': 305,
#   'number_of_reviews': 16,
#   'first_review': '1/26/11',
#   'last_review': '8/28/15',
#   'review_scores_rating': 100,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  35: {'id': 25463,
#   'listing_url': 'https://www.airbnb.com/rooms/25463',
#   'last_scraped': '10/3/18',
#   'name': 'Modern Zen in the Lower Haight',
#   'host_neighbourhood': 'Lower Haight',
#   'zipcode': 94117,
#   'latitude': 37.77728949,
#   'longitude': -122.4342115,
#   'property_type': 'Townhouse',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$110.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$150.00 ',
#   'cleaning_fee': '$30.00 ',
#   'guests_included': 1,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 2,
#   'maximum_nights': 29,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 3,
#   'availability_60': 32,
#   'availability_90': 57,
#   'availability_365': 57,
#   'number_of_reviews': 380,
#   'first_review': '10/26/10',
#   'last_review': '9/23/18',
#   'review_scores_rating': 98,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  36: {'id': 25662,
#   'listing_url': 'https://www.airbnb.com/rooms/25662',
#   'last_scraped': '10/3/18',
#   'name': 'Convenient, quiet, private!',
#   'host_neighbourhood': 'Potrero Hill',
#   'zipcode': 94107,
#   'latitude': 37.76212202,
#   'longitude': -122.395409,
#   'property_type': 'House',
#   'room_type': 'Private room',
#   'accommodates': 3,
#   'bathrooms': 1.0,
#   'bedrooms': 0,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$125.00 ',
#   'weekly_price': '$800.00 ',
#   'monthly_price': '',
#   'security_deposit': '$300.00 ',
#   'cleaning_fee': '$50.00 ',
#   'guests_included': 2,
#   'extra_people': '$30.00 ',
#   'minimum_nights': 4,
#   'maximum_nights': 180,
#   'calendar_updated': '2 months ago',
#   'has_availability': 't',
#   'availability_30': 8,
#   'availability_60': 20,
#   'availability_90': 42,
#   'availability_365': 315,
#   'number_of_reviews': 288,
#   'first_review': '7/17/10',
#   'last_review': '9/28/18',
#   'review_scores_rating': 95,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  37: {'id': 25927,
#   'listing_url': 'https://www.airbnb.com/rooms/25927',
#   'last_scraped': '10/3/18',
#   'name': 'CALEF HOUSE Rm 2, Priv Rm in Beaut SF Victorian',
#   'host_neighbourhood': 'Western Addition/NOPA',
#   'zipcode': 94115,
#   'latitude': 37.78894736,
#   'longitude': -122.4303064,
#   'property_type': 'House',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 1.5,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$110.00 ',
#   'weekly_price': '$900.00 ',
#   'monthly_price': '$3,100.00 ',
#   'security_deposit': '$500.00 ',
#   'cleaning_fee': '$35.00 ',
#   'guests_included': 1,
#   'extra_people': '$80.00 ',
#   'minimum_nights': 2,
#   'maximum_nights': 364,
#   'calendar_updated': '4 months ago',
#   'has_availability': 't',
#   'availability_30': 15,
#   'availability_60': 45,
#   'availability_90': 75,
#   'availability_365': 350,
#   'number_of_reviews': 66,
#   'first_review': '5/21/12',
#   'last_review': '9/27/18',
#   'review_scores_rating': 92,
#   'review_scores_accuracy': 9,
#   'review_scores_cleanliness': 9,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 9,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  38: {'id': 26488,
#   'listing_url': 'https://www.airbnb.com/rooms/26488',
#   'last_scraped': '10/3/18',
#   'name': 'Embarcadero High Rise with Views!',
#   'host_neighbourhood': 'South Beach',
#   'zipcode': 94105,
#   'latitude': 37.79089911,
#   'longitude': -122.3932944,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'bathrooms': 0.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$1,000.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$1,000.00 ',
#   'cleaning_fee': '$60.00 ',
#   'guests_included': 1,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 360,
#   'maximum_nights': 1825,
#   'calendar_updated': '18 months ago',
#   'has_availability': 't',
#   'availability_30': 30,
#   'availability_60': 60,
#   'availability_90': 90,
#   'availability_365': 365,
#   'number_of_reviews': 48,
#   'first_review': '6/1/10',
#   'last_review': '6/21/12',
#   'review_scores_rating': 97,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  39: {'id': 27025,
#   'listing_url': 'https://www.airbnb.com/rooms/27025',
#   'last_scraped': '10/3/18',
#   'name': 'Elegant, Antique Edwardian Apartment on Castro',
#   'host_neighbourhood': 'The Castro',
#   'zipcode': 94114,
#   'latitude': 37.76297968,
#   'longitude': -122.4313644,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$175.00 ',
#   'weekly_price': '$1,100.00 ',
#   'monthly_price': '$3,700.00 ',
#   'security_deposit': '$3,500.00 ',
#   'cleaning_fee': '$95.00 ',
#   'guests_included': 2,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 1125,
#   'calendar_updated': '7 months ago',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 0,
#   'availability_90': 0,
#   'availability_365': 184,
#   'number_of_reviews': 129,
#   'first_review': '5/14/10',
#   'last_review': '3/31/18',
#   'review_scores_rating': 100,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  40: {'id': 27028,
#   'listing_url': 'https://www.airbnb.com/rooms/27028',
#   'last_scraped': '10/3/18',
#   'name': 'Secret Mission Garden',
#   'host_neighbourhood': 'Mission District',
#   'zipcode': 94110,
#   'latitude': 37.76097556,
#   'longitude': -122.4215808,
#   'property_type': 'Condominium',
#   'room_type': 'Private room',
#   'accommodates': 4,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$199.00 ',
#   'weekly_price': '$9,999.00 ',
#   'monthly_price': '$9,999.00 ',
#   'security_deposit': '$0.00 ',
#   'cleaning_fee': '$75.00 ',
#   'guests_included': 2,
#   'extra_people': '$50.00 ',
#   'minimum_nights': 1,
#   'maximum_nights': 29,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 0,
#   'availability_90': 0,
#   'availability_365': 0,
#   'number_of_reviews': 24,
#   'first_review': '5/4/15',
#   'last_review': '8/9/18',
#   'review_scores_rating': 96,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  41: {'id': 32027,
#   'listing_url': 'https://www.airbnb.com/rooms/32027',
#   'last_scraped': '10/3/18',
#   'name': 'Luxury Two Bedroom Two Bath Suite - Lower Level.',
#   'host_neighbourhood': 'The Castro',
#   'zipcode': 94114,
#   'latitude': 37.76125915,
#   'longitude': -122.4372922,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 5,
#   'bathrooms': 2.0,
#   'bedrooms': 2,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$325.00 ',
#   'weekly_price': '$1,600.00 ',
#   'monthly_price': '$6,500.00 ',
#   'security_deposit': '$1,000.00 ',
#   'cleaning_fee': '$150.00 ',
#   'guests_included': 5,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 365,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 3,
#   'availability_60': 30,
#   'availability_90': 60,
#   'availability_365': 335,
#   'number_of_reviews': 2,
#   'first_review': '9/2/14',
#   'last_review': '10/9/14',
#   'review_scores_rating': 90,
#   'review_scores_accuracy': 9,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
# ...
#   'zipcode': 94110,
#   'latitude': 37.73351757,
#   'longitude': -122.4170642,
#   'property_type': 'Guest suite',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$125.00 ',
#   'weekly_price': '$800.00 ',
#   'monthly_price': '$3,000.00 ',
#   'security_deposit': '$150.00 ',
#   'cleaning_fee': '$60.00 ',
#   'guests_included': 1,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 2,
#   'maximum_nights': 29,
#   'calendar_updated': 'yesterday',
#   'has_availability': 't',
#   'availability_30': 1,
#   'availability_60': 11,
#   'availability_90': 29,
#   'availability_365': 298,
#   'number_of_reviews': 193,
#   'first_review': '3/21/14',
#   'last_review': '9/3/18',
#   'review_scores_rating': 96,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 9,
#   'review_scores_value': 10},
#  987: {'id': 2362619,
#   'listing_url': 'https://www.airbnb.com/rooms/2362619',
#   'last_scraped': '10/3/18',
#   'name': 'Cozy and quiet 1 BD in NoPa',
#   'host_neighbourhood': 'Western Addition/NOPA',
#   'zipcode': 94118,
#   'latitude': 37.77920331,
#   'longitude': -122.4458449,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$185.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$250.00 ',
#   'cleaning_fee': '$50.00 ',
#   'guests_included': 1,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 3,
#   'maximum_nights': 7,
#   'calendar_updated': '6 weeks ago',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 0,
#   'availability_90': 0,
#   'availability_365': 0,
#   'number_of_reviews': 64,
#   'first_review': '2/17/14',
#   'last_review': '8/20/18',
#   'review_scores_rating': 97,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 9,
#   'review_scores_value': 10},
#  988: {'id': 2366182,
#   'listing_url': 'https://www.airbnb.com/rooms/2366182',
#   'last_scraped': '10/3/18',
#   'name': 'Elegant, View Property-30 Nite Min-$11,000 a Month',
#   'host_neighbourhood': 'Nob Hill',
#   'zipcode': 94109,
#   'latitude': 37.79402658,
#   'longitude': -122.4151308,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 6,
#   'bathrooms': 2.0,
#   'bedrooms': 4,
#   'beds': 4,
#   'bed_type': 'Real Bed',
#   'price': '$375.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$1,000.00 ',
#   'cleaning_fee': '$400.00 ',
#   'guests_included': 6,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 365,
#   'calendar_updated': '4 months ago',
#   'has_availability': 't',
#   'availability_30': 6,
#   'availability_60': 36,
#   'availability_90': 66,
#   'availability_365': 341,
#   'number_of_reviews': 22,
#   'first_review': '5/5/14',
#   'last_review': '10/2/17',
#   'review_scores_rating': 87,
#   'review_scores_accuracy': 9,
#   'review_scores_cleanliness': 9,
#   'review_scores_checkin': 9,
#   'review_scores_communication': 9,
#   'review_scores_location': 9,
#   'review_scores_value': 8},
#  989: {'id': 2371394,
#   'listing_url': 'https://www.airbnb.com/rooms/2371394',
#   'last_scraped': '10/3/18',
#   'name': '1886 VICTORIAN, QUIET & PRIVATE, BEST AREA in SF!',
#   'host_neighbourhood': 'Duboce Triangle',
#   'zipcode': 94117,
#   'latitude': 37.76938789,
#   'longitude': -122.4332405,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$244.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$2,000.00 ',
#   'cleaning_fee': '$60.00 ',
#   'guests_included': 1,
#   'extra_people': '$15.00 ',
#   'minimum_nights': 6,
#   'maximum_nights': 39,
#   'calendar_updated': 'a week ago',
#   'has_availability': 't',
#   'availability_30': 6,
#   'availability_60': 6,
#   'availability_90': 6,
#   'availability_365': 6,
#   'number_of_reviews': 36,
#   'first_review': '10/1/14',
#   'last_review': '9/28/18',
#   'review_scores_rating': 99,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  990: {'id': 2374361,
#   'listing_url': 'https://www.airbnb.com/rooms/2374361',
#   'last_scraped': '10/3/18',
#   'name': 'Amazing Victorian Flat Noe Valley',
#   'host_neighbourhood': 'Glen Park',
#   'zipcode': 94131,
#   'latitude': 37.73883604,
#   'longitude': -122.425608,
#   'property_type': 'Guest suite',
#   'room_type': 'Entire home/apt',
#   'accommodates': 4,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$113.00 ',
#   'weekly_price': '$1,000.00 ',
#   'monthly_price': '$3,600.00 ',
#   'security_deposit': '$0.00 ',
#   'cleaning_fee': '$100.00 ',
#   'guests_included': 2,
#   'extra_people': '$10.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 1125,
#   'calendar_updated': '6 months ago',
#   'has_availability': 't',
#   'availability_30': 26,
#   'availability_60': 42,
#   'availability_90': 72,
#   'availability_365': 347,
#   'number_of_reviews': 16,
#   'first_review': '6/6/14',
#   'last_review': '3/26/18',
#   'review_scores_rating': 98,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  991: {'id': 2374370,
#   'listing_url': 'https://www.airbnb.com/rooms/2374370',
#   'last_scraped': '10/3/18',
#   'name': 'Queen bed, en suite bath, close to shops & cafes!',
#   'host_neighbourhood': 'Western Addition/NOPA',
#   'zipcode': 94115,
#   'latitude': 37.78784144,
#   'longitude': -122.4308222,
#   'property_type': 'Apartment',
#   'room_type': 'Private room',
#   'accommodates': 3,
#   'bathrooms': 2.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$99.00 ',
#   'weekly_price': '',
#   'monthly_price': '$4,650.00 ',
#   'security_deposit': '',
#   'cleaning_fee': '$40.00 ',
#   'guests_included': 1,
#   'extra_people': '$15.00 ',
#   'minimum_nights': 1,
#   'maximum_nights': 10000,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 3,
#   'availability_60': 28,
#   'availability_90': 38,
#   'availability_365': 40,
#   'number_of_reviews': 338,
#   'first_review': '4/16/14',
#   'last_review': '9/28/18',
#   'review_scores_rating': 97,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  992: {'id': 2374873,
#   'listing_url': 'https://www.airbnb.com/rooms/2374873',
#   'last_scraped': '10/3/18',
#   'name': '1 bedroom home, walk to BART SFSU',
#   'host_neighbourhood': 'Ingleside',
#   'zipcode': 94112,
#   'latitude': 37.72136915,
#   'longitude': -122.4487295,
#   'property_type': 'Guest suite',
#   'room_type': 'Entire home/apt',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$79.00 ',
#   'weekly_price': '',
#   'monthly_price': '$2,150.00 ',
#   'security_deposit': '$500.00 ',
#   'cleaning_fee': '$175.00 ',
#   'guests_included': 2,
#   'extra_people': '$5.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 1125,
#   'calendar_updated': '3 days ago',
#   'has_availability': 't',
#   'availability_30': 5,
#   'availability_60': 35,
#   'availability_90': 65,
#   'availability_365': 340,
#   'number_of_reviews': 14,
#   'first_review': '8/10/14',
#   'last_review': '5/28/18',
#   'review_scores_rating': 97,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  993: {'id': 2387068,
#   'listing_url': 'https://www.airbnb.com/rooms/2387068',
#   'last_scraped': '10/3/18',
#   'name': 'Quiet Neighborhood, Convenient, Street parking',
#   'host_neighbourhood': 'Balboa Terrace',
#   'zipcode': 94112,
#   'latitude': 37.72642728,
#   'longitude': -122.4617544,
#   'property_type': 'Condominium',
#   'room_type': 'Private room',
#   'accommodates': 2,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$100.00 ',
#   'weekly_price': '$700.00 ',
#   'monthly_price': '$2,500.00 ',
#   'security_deposit': '$500.00 ',
#   'cleaning_fee': '$40.00 ',
#   'guests_included': 1,
#   'extra_people': '$0.00 ',
#   'minimum_nights': 3,
#   'maximum_nights': 90,
#   'calendar_updated': '3 weeks ago',
#   'has_availability': 't',
#   'availability_30': 1,
#   'availability_60': 31,
#   'availability_90': 61,
#   'availability_365': 333,
#   'number_of_reviews': 62,
#   'first_review': '3/30/14',
#   'last_review': '9/11/18',
#   'review_scores_rating': 96,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  994: {'id': 2391772,
#   'listing_url': 'https://www.airbnb.com/rooms/2391772',
#   'last_scraped': '10/3/18',
#   'name': 'Beautiful and cozy Dolores loft',
#   'host_neighbourhood': 'Duboce Triangle',
#   'zipcode': 94114,
#   'latitude': 37.7656597,
#   'longitude': -122.4339866,
#   'property_type': 'Loft',
#   'room_type': 'Entire home/apt',
#   'accommodates': 3,
#   'bathrooms': 1.0,
#   'bedrooms': 0,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$136.00 ',
#   'weekly_price': '$1,399.00 ',
#   'monthly_price': '$4,995.00 ',
#   'security_deposit': '$555.00 ',
#   'cleaning_fee': '$125.00 ',
#   'guests_included': 2,
#   'extra_people': '$10.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 365,
#   'calendar_updated': '5 months ago',
#   'has_availability': 't',
#   'availability_30': 3,
#   'availability_60': 33,
#   'availability_90': 63,
#   'availability_365': 337,
#   'number_of_reviews': 53,
#   'first_review': '3/2/14',
#   'last_review': '8/10/18',
#   'review_scores_rating': 86,
#   'review_scores_accuracy': 9,
#   'review_scores_cleanliness': 8,
#   'review_scores_checkin': 9,
#   'review_scores_communication': 9,
#   'review_scores_location': 10,
#   'review_scores_value': 8},
#  995: {'id': 2396847,
#   'listing_url': 'https://www.airbnb.com/rooms/2396847',
#   'last_scraped': '10/3/18',
#   'name': 'Luxurious, Modern, Fully-Equipped Studio',
#   'host_neighbourhood': 'Richmond District',
#   'zipcode': 94121,
#   'latitude': 37.77915101,
#   'longitude': -122.4785733,
#   'property_type': 'Apartment',
#   'room_type': 'Entire home/apt',
#   'accommodates': 3,
#   'bathrooms': 1.0,
#   'bedrooms': 0,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$125.00 ',
#   'weekly_price': '$820.00 ',
#   'monthly_price': '$2,850.00 ',
#   'security_deposit': '$250.00 ',
#   'cleaning_fee': '$40.00 ',
#   'guests_included': 2,
#   'extra_people': '$10.00 ',
#   'minimum_nights': 3,
#   'maximum_nights': 1125,
#   'calendar_updated': '2 months ago',
#   'has_availability': 't',
#   'availability_30': 7,
#   'availability_60': 22,
#   'availability_90': 37,
#   'availability_365': 275,
#   'number_of_reviews': 277,
#   'first_review': '5/17/14',
#   'last_review': '9/24/18',
#   'review_scores_rating': 97,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 9,
#   'review_scores_value': 10},
#  996: {'id': 2397852,
#   'listing_url': 'https://www.airbnb.com/rooms/2397852',
#   'last_scraped': '10/3/18',
#   'name': 'Modern 2King 2baths garden suite w/parking.',
#   'host_neighbourhood': 'Richmond District',
#   'zipcode': 94121,
#   'latitude': 37.77424186,
#   'longitude': -122.5016747,
#   'property_type': 'Guest suite',
#   'room_type': 'Entire home/apt',
#   'accommodates': 6,
#   'bathrooms': 2.0,
#   'bedrooms': 2,
#   'beds': 4,
#   'bed_type': 'Real Bed',
#   'price': '$306.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$500.00 ',
#   'cleaning_fee': '$125.00 ',
#   'guests_included': 4,
#   'extra_people': '$35.00 ',
#   'minimum_nights': 2,
#   'maximum_nights': 21,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 19,
#   'availability_90': 33,
#   'availability_365': 118,
#   'number_of_reviews': 64,
#   'first_review': '9/19/15',
#   'last_review': '9/23/18',
#   'review_scores_rating': 99,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  997: {'id': 2397858,
#   'listing_url': 'https://www.airbnb.com/rooms/2397858',
#   'last_scraped': '10/3/18',
#   'name': 'Modern Light Airy House by GG Park/Beach w/parking',
#   'host_neighbourhood': 'Richmond District',
#   'zipcode': 94121,
#   'latitude': 37.77026055,
#   'longitude': -122.4990148,
#   'property_type': 'House',
#   'room_type': 'Entire home/apt',
#   'accommodates': 13,
#   'bathrooms': 3.0,
#   'bedrooms': 4,
#   'beds': 8,
#   'bed_type': 'Real Bed',
#   'price': '$889.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$1,500.00 ',
#   'cleaning_fee': '$285.00 ',
#   'guests_included': 8,
#   'extra_people': '$50.00 ',
#   'minimum_nights': 2,
#   'maximum_nights': 21,
#   'calendar_updated': 'a week ago',
#   'has_availability': 't',
#   'availability_30': 0,
#   'availability_60': 0,
#   'availability_90': 0,
#   'availability_365': 85,
#   'number_of_reviews': 39,
#   'first_review': '1/1/16',
#   'last_review': '9/27/18',
#   'review_scores_rating': 99,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 9},
#  998: {'id': 2400409,
#   'listing_url': 'https://www.airbnb.com/rooms/2400409',
#   'last_scraped': '10/3/18',
#   'name': 'Private cottage, easy location/parking, WiFi',
#   'host_neighbourhood': 'Sunnyside',
#   'zipcode': 94127,
#   'latitude': 37.73302629,
#   'longitude': -122.4497917,
#   'property_type': 'Guesthouse',
#   'room_type': 'Entire home/apt',
#   'accommodates': 4,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 2,
#   'bed_type': 'Real Bed',
#   'price': '$177.00 ',
#   'weekly_price': '',
#   'monthly_price': '',
#   'security_deposit': '$0.00 ',
#   'cleaning_fee': '$110.00 ',
#   'guests_included': 2,
#   'extra_people': '$20.00 ',
#   'minimum_nights': 3,
#   'maximum_nights': 14,
#   'calendar_updated': 'today',
#   'has_availability': 't',
#   'availability_30': 4,
#   'availability_60': 20,
#   'availability_90': 49,
#   'availability_365': 49,
#   'number_of_reviews': 117,
#   'first_review': '3/20/14',
#   'last_review': '9/24/18',
#   'review_scores_rating': 98,
#   'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 10,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10},
#  999: {'id': 2404647,
#   'listing_url': 'https://www.airbnb.com/rooms/2404647',
#   'last_scraped': '10/3/18',
#   'name': 'Room with a View in Noe Valley',
#   'host_neighbourhood': 'Noe Valley',
#   'zipcode': 94131,
#   'latitude': 37.7480203,
#   'longitude': -122.4352134,
#   'property_type': 'Apartment',
#   'room_type': 'Private room',
#   'accommodates': 1,
#   'bathrooms': 1.0,
#   'bedrooms': 1,
#   'beds': 1,
#   'bed_type': 'Real Bed',
#   'price': '$89.00 ',
#   'weekly_price': '$525.00 ',
#   'monthly_price': '$2,200.00 ',
#   'security_deposit': '$500.00 ',
#   'cleaning_fee': '$75.00 ',
#   'guests_included': 1,
#   'extra_people': '$20.00 ',
#   'minimum_nights': 30,
#   'maximum_nights': 60,
#   'calendar_updated': '6 months ago',
#   'has_availability': 't',
#   'availability_30': 30,
#   'availability_60': 60,
#   'availability_90': 89,
#   'availability_365': 89,
#   'number_of_reviews': 11,
#   'first_review': '5/7/14',
#   'last_review': '10/20/17',
#   'review_scores_rating': 90,
#   'review_scores_accuracy': 9,
#   'review_scores_cleanliness': 8,
#   'review_scores_checkin': 9,
#   'review_scores_communication': 9,
#   'review_scores_location': 9,
#   'review_scores_value': 8},
#  ...}
